# %%
import tensorflow as tf
from tensorflow.python.keras import backend as K
from tensorflow.python.keras import metrics
from tensorflow.python.keras import losses
from tensorflow.python.keras import optimizers
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Flatten
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D

# %%
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
train_images = train_images / 255.0
print("x_train shape:", train_images.shape, "labels train shape:", train_labels.shape)
# Out:
# x_train shape: (60000, 28, 28) labels train shape: (60000,)

# %%
test_images = test_images / 255.0
ntrain = train_images[10000:30000]
ntlabels = train_labels[10000:30000]

# %%
ntrain = ntrain.reshape(20000, 28, 28, 1)
print(ntrain.shape)
# Out:
# (20000, 28, 28, 1)

# %%
test_images = test_images.reshape(10000, 28, 28, 1)
print(test_images.shape)
# Out:
# (10000, 28, 28, 1)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation = 'relu', input_shape = (28,28,1)))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(5408, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 5408)              29251872
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                54090
# =================================================================
# Total params: 29,306,282
# Trainable params: 29,306,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = tf.optimizers.Adam(), 
              loss = 'sparse_categorical_crossentropy',
              metrics = [metrics.sparse_categorical_accuracy])

# %%
model.fit(ntrain, ntlabels, epochs=10)
# Out:
# Train on 20000 samples
# Epoch 1/10
# 20000/20000 [==============================] - 166s 8ms/sample - loss: 0.4591 - sparse_categorical_accuracy: 0.8366
# Epoch 2/10
# 20000/20000 [==============================] - 162s 8ms/sample - loss: 0.2872 - sparse_categorical_accuracy: 0.8937
# Epoch 3/10
# 20000/20000 [==============================] - 163s 8ms/sample - loss: 0.2249 - sparse_categorical_accuracy: 0.9160
# Epoch 4/10
# 20000/20000 [==============================] - 115s 6ms/sample - loss: 0.1800 - sparse_categorical_accuracy: 0.9334
# Epoch 5/10
# 20000/20000 [==============================] - 111s 6ms/sample - loss: 0.1462 - sparse_categorical_accuracy: 0.9457s - lo
# Epoch 6/10
# 20000/20000 [==============================] - 111s 6ms/sample - loss: 0.1184 - sparse_categorical_accuracy: 0.9545
# Epoch 7/10
# 20000/20000 [==============================] - 111s 6ms/sample - loss: 0.0939 - sparse_categorical_accuracy: 0.9664
# Epoch 8/10
# 20000/20000 [==============================] - 112s 6ms/sample - loss: 0.0779 - sparse_categorical_accuracy: 0.9701
# Epoch 9/10
# 20000/20000 [==============================] - 112s 6ms/sample - loss: 0.0655 - sparse_categorical_accuracy: 0.9758
# Epoch 10/10
# 20000/20000 [==============================] - 112s 6ms/sample - loss: 0.0530 - sparse_categorical_accuracy: 0.9810s - loss:

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.8994
